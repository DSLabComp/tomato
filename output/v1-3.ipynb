# %% [markdown]
# # v1-3 Pre-training
# https://www.tensorflow.org/tutorials/images/transfer_learning?hl=ko
#
# 1. Code, image 정리
# 2. Epochs 추가
# 3. img_height, img_width 변경 (180 -> 256)
# 4. Pre-training: 높은 initial value
# 5. Fine-tuning 예정

# %%
exp_name = 'v1-3'

from util import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
try:
    for gpu in tf.config.experimental.list_physical_devices('GPU'):
        tf.config.experimental.set_memory_growth(gpu, True)
except RuntimeError as e:
    print(e)

# %%
batch_size = 32
img_height = 256
img_width  = 256
img_size   = (img_height, img_width)
RS         = 42

# %%
data_dir = join(PATH.INPUT, 'train')
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset='training', shuffle=True, seed=RS, image_size=img_size, batch_size=batch_size
)
val_ds   = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset='validation', shuffle=True, seed=RS, image_size=img_size, batch_size=batch_size
)
full_ds  = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, shuffle=True, seed=RS, image_size=img_size, batch_size=batch_size
)

class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)

for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
    
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds   = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
full_ds  = full_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 13861 files belonging to 10 classes.
# Using 11089 files for training.
# Found 13861 files belonging to 10 classes.
# Using 2772 files for validation.
# Found 13861 files belonging to 10 classes.
# ['Tomato_D01', 'Tomato_D04', 'Tomato_D05', 'Tomato_D07', 'Tomato_D08', 'Tomato_D09', 'Tomato_H', 'Tomato_P03', 'Tomato_P05', 'Tomato_R01']
# (32, 256, 256, 3)
# (32,)

# %%
from tensorflow.keras import layers

# mirrored_strategy = tf.distribute.MirroredStrategy()
# with mirrored_strategy.scope():

data_augmentation = Sequential([
    layers.experimental.preprocessing.RandomFlip('horizontal', input_shape=(img_height, img_width, 3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1)
])
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)


img_shape = img_size + (3,)
base_model = keras.applications.MobileNetV2(input_shape=img_shape, include_top=False, weights='imagenet')
base_model.trainable = False

    
image_batch, label_batch = next(iter(train_ds))
feature_batch = base_model(image_batch)
print(feature_batch.shape)

global_average_layer = layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)

prediction_layer = layers.Dense(num_classes)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)


inputs = keras.Input(shape=(img_height, img_width, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = keras.Model(inputs, outputs)

# base_learning_rate = 1e-3
# optimizer = keras.optimizers.RMSprop(learning_rate=base_learning_rate)
optimizer = 'adam'

model.compile(optimizer=optimizer, loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# (32, 8, 8, 1280)
# (32, 1280)
# (32, 10)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 256, 256, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 256, 256, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_224 (Functi (None, 8, 8, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                12810
# =================================================================
# Total params: 2,270,794
# Trainable params: 12,810
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

epochs = 100
history = model.fit(
    train_ds, validation_data=val_ds, epochs=epochs,
    callbacks=[EarlyStopping(monitor='val_loss', mode='min', patience=10)]
)
# Out:
# Epoch 1/100
# 347/347 [==============================] - 16s 40ms/step - loss: 0.7262 - accuracy: 0.7768 - val_loss: 0.4958 - val_accuracy: 0.8676
# Epoch 2/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.4665 - accuracy: 0.8617 - val_loss: 0.4109 - val_accuracy: 0.8896
# Epoch 3/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.4070 - accuracy: 0.8734 - val_loss: 0.3763 - val_accuracy: 0.8929
# Epoch 4/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3778 - accuracy: 0.8854 - val_loss: 0.3675 - val_accuracy: 0.8925
# Epoch 5/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3543 - accuracy: 0.8881 - val_loss: 0.3523 - val_accuracy: 0.8950
# Epoch 6/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3367 - accuracy: 0.8918 - val_loss: 0.3402 - val_accuracy: 0.8986
# Epoch 7/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.3342 - accuracy: 0.8950 - val_loss: 0.3362 - val_accuracy: 0.9008
# Epoch 8/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.3215 - accuracy: 0.8969 - val_loss: 0.3165 - val_accuracy: 0.9073
# Epoch 9/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3167 - accuracy: 0.8987 - val_loss: 0.3249 - val_accuracy: 0.9033
# Epoch 10/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3139 - accuracy: 0.8984 - val_loss: 0.3091 - val_accuracy: 0.9102
# Epoch 11/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3010 - accuracy: 0.9020 - val_loss: 0.3121 - val_accuracy: 0.9084
# Epoch 12/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3031 - accuracy: 0.9013 - val_loss: 0.3104 - val_accuracy: 0.9055
# Epoch 13/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.3009 - accuracy: 0.9013 - val_loss: 0.2998 - val_accuracy: 0.9098
# Epoch 14/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2949 - accuracy: 0.9024 - val_loss: 0.3215 - val_accuracy: 0.9012
# Epoch 15/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2942 - accuracy: 0.9057 - val_loss: 0.3073 - val_accuracy: 0.9084
# Epoch 16/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2918 - accuracy: 0.9042 - val_loss: 0.2936 - val_accuracy: 0.9058
# Epoch 17/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2851 - accuracy: 0.9132 - val_loss: 0.2935 - val_accuracy: 0.9109
# Epoch 18/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2995 - accuracy: 0.9020 - val_loss: 0.3100 - val_accuracy: 0.9120
# Epoch 19/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2874 - accuracy: 0.9039 - val_loss: 0.2977 - val_accuracy: 0.9145
# Epoch 20/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2844 - accuracy: 0.9052 - val_loss: 0.2931 - val_accuracy: 0.9177
# Epoch 21/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2713 - accuracy: 0.9096 - val_loss: 0.3050 - val_accuracy: 0.9113
# Epoch 22/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2881 - accuracy: 0.9068 - val_loss: 0.3062 - val_accuracy: 0.9095
# Epoch 23/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2767 - accuracy: 0.9074 - val_loss: 0.3297 - val_accuracy: 0.8979
# Epoch 24/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2645 - accuracy: 0.9130 - val_loss: 0.2890 - val_accuracy: 0.9131
# Epoch 25/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2755 - accuracy: 0.9095 - val_loss: 0.3039 - val_accuracy: 0.9123
# Epoch 26/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2727 - accuracy: 0.9084 - val_loss: 0.2895 - val_accuracy: 0.9145
# Epoch 27/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2691 - accuracy: 0.9111 - val_loss: 0.3048 - val_accuracy: 0.9138
# Epoch 28/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2756 - accuracy: 0.9079 - val_loss: 0.2967 - val_accuracy: 0.9120
# Epoch 29/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2750 - accuracy: 0.9086 - val_loss: 0.2952 - val_accuracy: 0.9102
# Epoch 30/100
# 347/347 [==============================] - 13s 37ms/step - loss: 0.2664 - accuracy: 0.9086 - val_loss: 0.2933 - val_accuracy: 0.9152
# Epoch 31/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2685 - accuracy: 0.9094 - val_loss: 0.3133 - val_accuracy: 0.9095
# Epoch 32/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2674 - accuracy: 0.9121 - val_loss: 0.2891 - val_accuracy: 0.9131
# Epoch 33/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2683 - accuracy: 0.9108 - val_loss: 0.2783 - val_accuracy: 0.9174
# Epoch 34/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2699 - accuracy: 0.9077 - val_loss: 0.3149 - val_accuracy: 0.9069
# Epoch 35/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2781 - accuracy: 0.9062 - val_loss: 0.3136 - val_accuracy: 0.9048
# Epoch 36/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2693 - accuracy: 0.9112 - val_loss: 0.3067 - val_accuracy: 0.9120
# Epoch 37/100
# 347/347 [==============================] - 14s 39ms/step - loss: 0.2698 - accuracy: 0.9100 - val_loss: 0.3138 - val_accuracy: 0.9058
# Epoch 38/100
# 347/347 [==============================] - 13s 39ms/step - loss: 0.2648 - accuracy: 0.9131 - val_loss: 0.3102 - val_accuracy: 0.9098
# Epoch 39/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2623 - accuracy: 0.9110 - val_loss: 0.3115 - val_accuracy: 0.9087
# Epoch 40/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2663 - accuracy: 0.9111 - val_loss: 0.3081 - val_accuracy: 0.9069
# Epoch 41/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2629 - accuracy: 0.9133 - val_loss: 0.3090 - val_accuracy: 0.9141
# Epoch 42/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2715 - accuracy: 0.9109 - val_loss: 0.3054 - val_accuracy: 0.9113
# Epoch 43/100
# 347/347 [==============================] - 13s 38ms/step - loss: 0.2633 - accuracy: 0.9134 - val_loss: 0.2863 - val_accuracy: 0.9192

# %%
hist         = history.history
epochs_range = range(len(hist['loss']))

plt.figure(figsize=(16, 8))
for idx, metric in enumerate(['accuracy', 'loss']):
    train_metric = hist[metric]
    val_metric   = hist[f'val_{metric}']
    
    plt.subplot(1, 2, idx+1)
    plt.plot(epochs_range, train_metric, label=f'training {metric}')
    plt.plot(epochs_range, val_metric, label=f'validation {metric}')
    plt.legend(fontsize='x-large');  plt.grid()
    plt.title(f'Training and Validation {metric}')
    
plt.show()

# %%
# base_model.trainable = True


# # Let's take a look to see how many layers are in the base model
# print("Number of layers in the base model: ", len(base_model.layers))

# # Fine-tune from this layer onwards
# fine_tune_at = 100

# # Freeze all the layers before the `fine_tune_at` layer
# for layer in base_model.layers[:fine_tune_at]:
#     layer.trainable = False


# # optimizer = keras.optimizers.RMSprop(learning_rate=base_learning_rate)
# optimizer = 'adam'
# model.compile(optimizer=optimizer, loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
# model.summary()

# %%
# fine_tune_epochs = 100
# total_epochs = epochs + fine_tune_epochs

# history = model.fit(
#     train_ds, validation_data=val_ds, epochs=total_epochs, initial_epoch=history.epoch[-1],
#     callbacks=[EarlyStopping(monitor='val_loss', mode='min', patience=10)]
# )

# %%
# hist         = history.history
# epochs_range = range(len(hist['loss']))

# plt.figure(figsize=(16, 8))
# for idx, metric in enumerate(['accuracy', 'loss']):
#     train_metric = hist[metric]
#     val_metric   = hist[f'val_{metric}']
    
#     plt.subplot(1, 2, idx+1)
#     plt.plot(epochs_range, train_metric, label=f'training {metric}')
#     plt.plot(epochs_range, val_metric, label=f'validation {metric}')
#     plt.legend(fontsize='x-large');  plt.grid()
#     plt.title(f'Training and Validation {metric}')
    
# plt.show()

# %%
data_dir = join(PATH.INPUT, 'test')

img_arrays = []
names      = []
for path, name in sorted(list_files(data_dir), key=lambda e: int(''.join(filter(str.isdigit, e[1])))):
    img = keras.preprocessing.image.load_img(path, target_size=img_size)
    img_array = keras.preprocessing.image.img_to_array(img)
    img_arrays.append(img_array)
    names.append(name)
img_arrays = np.array(img_arrays)

predictions = model.predict(img_arrays)
predictions = np.argmax(predictions, axis=1)

sub = pd.DataFrame({'file_name': names, 'answer': predictions})
output_path = join(PATH.OUTPUT, f'{exp_name}.csv')
sub.to_csv(output_path, index=None)
